# %%
from io import BytesIO
import os
import dotenv
import base64
import pyautogui
import matplotlib.pyplot as plt
import math
from time import time, sleep
from typing import Tuple, List
from PIL import Image
import yaml

from langchain_core.messages import HumanMessage, BaseMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()
# Out:
# True

# %%
with open("screen_regions.yaml") as f:
    screen_regions = yaml.safe_load(f)

screen_regions
# Out:
# {'confirm_button_1': [1073, 976],
#  'hobart_1': [984, 774],
#  'kodiak_1': [448, 567],
#  'map_bottom_right_1': [1110, 921],
#  'map_top_left_1': [365, 404],
#  'next_round_button': [568, 924],
#  'screen_bot_right': [1149, 1000],
#  'screen_top_left': [9, 151]}

# %%
from geoguessr_bot import GeoBot

bot = GeoBot(screen_regions=screen_regions)

bot.screen_xywh
# Out:
# (9, 151, 1140, 849)

# %%
screenshot = pyautogui.screenshot(region=bot.screen_xywh)
plt.imshow(screenshot)
plt.show()

# %%
minimap = pyautogui.screenshot(region=bot.minimap_xywh)
plt.imshow(minimap)
plt.plot(bot.hobart_x-bot.map_x, bot.hobart_y-bot.map_y, 'ro', label='Hobart')
plt.plot(bot.kodiak_x-bot.map_x, bot.kodiak_y-bot.map_y, 'ro', label='Kodiak')
plt.show()
